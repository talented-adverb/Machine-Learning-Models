# %%
from pycaret.regression import *

# %%
from pycaret.utils import version
version()
# Out:
# '3.3.0'

# %%
from pycaret.datasets import get_data
dataSets = get_data('index')
# Out:
#                              Dataset    Data Types  \
# 0                            anomaly  Multivariate
# 1                             france  Multivariate
# 2                            germany  Multivariate
# 3                               bank  Multivariate
# 4                              blood  Multivariate
# 5                             cancer  Multivariate
# 6                             credit  Multivariate
# 7                           diabetes  Multivariate
# 8                    electrical_grid  Multivariate
# 9                           employee  Multivariate
# 10                             heart  Multivariate
# 11                     heart_disease  Multivariate
# 12                         hepatitis  Multivariate
# 13                            income  Multivariate
# 14                             juice  Multivariate
# 15                               nba  Multivariate
# 16                              wine  Multivariate
# ...

# %%
bostonDataSet = get_data("boston")    # SN is 46
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#     black  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
from pycaret.regression import *
s = setup(data =  bostonDataSet, target='medv')

# Other Parameters:
# train_size = 0.7
# data_split_shuffle = False
# Out:
# <style type="text/css">
# #T_f8d80_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_f8d80">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f8d80_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_f8d80_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f8d80_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f8d80_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_f8d80_row0_col1" class="data row0 col1" >1670</td>
#     </tr>
#     <tr>
#       <th id="T_f8d80_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f8d80_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_f8d80_row1_col1" class="data row1 col1" >medv</td>
#     </tr>
#     <tr>
#       <th id="T_f8d80_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
from pickle import TRUE
from pycaret.datasets import get_data
from pycaret.regression import *

bostonDataSet = get_data("boston", verbose=False)
setup(data = bostonDataSet, target='medv', train_size = 0.7, data_split_shuffle = False, verbose=False)
cm = compare_models()
# Out:
# <style type="text/css">
# #T_df890 th {
#   text-align: left;
# }
# ...

# %%
from pycaret.datasets import get_data
from pycaret.regression import *

insuranceDataSet = get_data("insurance", verbose=False)
setup(data = insuranceDataSet, target='charges', train_size = 0.7, data_split_shuffle = False, verbose=False)
cm = compare_models()
# Out:
# <style type="text/css">
# #T_aa697 th {
#   text-align: left;
# }
# ...

# %%
bostonDataSet.to_csv('bostonDataSet.csv',index=False)

# %%
from IPython.display import FileLink
FileLink('bostonDataSet.csv')
# Out:
# C:\Users\pratham\bostonDataSet.csv

# %%
from IPython.display import FileLink, FileLinks

# Use the file upload widget to upload a file
upload_widget = FileLink('bostonDataSet.csv', result_html_prefix="Upload successful! ")
upload_widget
# Out:
# C:\Users\pratham\bostonDataSet.csv

# %%
import pandas as pd 
myDataset=pd.read_csv('bostonDataset.csv')

# %%
myDataset.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#     black  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
from pycaret.regression import *
s = setup(data =  bostonDataSet, target='medv')
cm=compare_models()
# Out:
# <style type="text/css">
# #T_2c1cd_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_2c1cd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2c1cd_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_2c1cd_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2c1cd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2c1cd_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_2c1cd_row0_col1" class="data row0 col1" >7375</td>
#     </tr>
#     <tr>
#       <th id="T_2c1cd_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2c1cd_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_2c1cd_row1_col1" class="data row1 col1" >medv</td>
#     </tr>
#     <tr>
#       <th id="T_2c1cd_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
setup(data = bostonDataSet, target = 'medv',
      normalize = True, normalize_method = 'zscore')
cm = compare_models()
# Out:
# <style type="text/css">
# #T_c2487_row8_col1, #T_c2487_row12_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_c2487">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c2487_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_c2487_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c2487_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c2487_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_c2487_row0_col1" class="data row0 col1" >4303</td>
#     </tr>
#     <tr>
#       <th id="T_c2487_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c2487_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_c2487_row1_col1" class="data row1 col1" >medv</td>
#     </tr>
#     <tr>
#       <th id="T_c2487_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
bostonDataSet.columns = bostonDataSet.columns.str.replace(' ', '_')
setup(data = bostonDataSet, target = 'medv',
      feature_selection = True, feature_selection_method = 'classic')
cm = compare_models()
# Out:
#   File "C:\Users\pratham\anaconda3\Lib\site-packages\joblib\externals\loky\backend\context.py", line 217, in _count_physical_cores
#     raise ValueError(
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000455 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 926
# [LightGBM] [Info] Number of data points in the train set: 354, number of used features: 13
# [LightGBM] [Info] Start training from score 22.749153
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %%
setup(data = bostonDataSet, target = 'medv',
      remove_outliers = True, outliers_method = "iforest", outliers_threshold = 0.05)
cm = compare_models()
# Out:
# <style type="text/css">
# #T_095f4_row8_col1, #T_095f4_row12_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_095f4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_095f4_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_095f4_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_095f4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_095f4_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_095f4_row0_col1" class="data row0 col1" >3000</td>
#     </tr>
#     <tr>
#       <th id="T_095f4_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_095f4_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_095f4_row1_col1" class="data row1 col1" >medv</td>
#     </tr>
#     <tr>
#       <th id="T_095f4_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
setup(data = bostonDataSet, target = 'medv',
      transformation = True, transformation_method = 'yeo-johnson')
cm = compare_models()
# Out:
# <style type="text/css">
# #T_9002c_row8_col1, #T_9002c_row12_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_9002c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9002c_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_9002c_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9002c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9002c_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_9002c_row0_col1" class="data row0 col1" >7169</td>
#     </tr>
#     <tr>
#       <th id="T_9002c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9002c_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_9002c_row1_col1" class="data row1 col1" >medv</td>
#     </tr>
#     <tr>
#       <th id="T_9002c_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
setup(data = bostonDataSet, target = 'medv',
      pca = True, pca_method = 'linear')
cm=compare_models()
# Out:
# <style type="text/css">
# #T_c17d5_row8_col1, #T_c17d5_row12_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_c17d5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c17d5_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_c17d5_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c17d5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c17d5_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_c17d5_row0_col1" class="data row0 col1" >8412</td>
#     </tr>
#     <tr>
#       <th id="T_c17d5_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c17d5_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_c17d5_row1_col1" class="data row1 col1" >medv</td>
#     </tr>
#     <tr>
#       <th id="T_c17d5_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
setup(data = bostonDataSet, target = 'medv',
      remove_outliers = True, outliers_threshold = 0.05,
      normalize = True, normalize_method = 'zscore',
      transformation = True, transformation_method = 'yeo-johnson',
      data_split_shuffle = False)
cm = compare_models()
# Out:
# <style type="text/css">
# #T_6a934_row8_col1, #T_6a934_row12_col1, #T_6a934_row14_col1, #T_6a934_row16_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_6a934">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6a934_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_6a934_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6a934_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6a934_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_6a934_row0_col1" class="data row0 col1" >1161</td>
#     </tr>
#     <tr>
#       <th id="T_6a934_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6a934_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_6a934_row1_col1" class="data row1 col1" >medv</td>
#     </tr>
#     <tr>
# ...

# %%
from pycaret.datasets import get_data
from pycaret.regression import *

bostonDataSet = get_data("boston", verbose=False)    # SN is 46
setup(data =  bostonDataSet, target='medv', verbose=False)

rfModel = create_model('rf')
# Explore more parameters
# Out:
# <style type="text/css">
# #T_4b39e_row10_col0, #T_4b39e_row10_col1, #T_4b39e_row10_col2, #T_4b39e_row10_col3, #T_4b39e_row10_col4, #T_4b39e_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_4b39e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4b39e_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_4b39e_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_4b39e_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_4b39e_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_4b39e_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_4b39e_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...

# %%
# Select top 10 rows from boston dataset
newDataSet = get_data("boston").iloc[:10]
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#     black  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
newDataSet.head(10)
# Out:
#       crim    zn  indus  chas    nox     rm    age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575   65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421   78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185   61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998   45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147   54.2  6.0622    3  222     18.7
# 5  0.02985   0.0   2.18     0  0.458  6.430   58.7  6.0622    3  222     18.7
# 6  0.08829  12.5   7.87     0  0.524  6.012   66.6  5.5605    5  311     15.2
# 7  0.14455  12.5   7.87     0  0.524  6.172   96.1  5.9505    5  311     15.2
# 8  0.21124  12.5   7.87     0  0.524  5.631  100.0  6.0821    5  311     15.2
# 9  0.17004  12.5   7.87     0  0.524  6.004   85.9  6.5921    5  311     15.2
#
#     black  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# ...

# %%
newPredictions = predict_model(rfModel, data = newDataSet)
newPredictions
# Out:
# <style type="text/css">
# </style>
# <table id="T_c34ca">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c34ca_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_c34ca_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_c34ca_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_c34ca_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_c34ca_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_c34ca_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_c34ca_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c34ca_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c34ca_row0_col0" class="data row0 col0" >Random Forest Regressor</td>
#       <td id="T_c34ca_row0_col1" class="data row0 col1" >1.2210</td>
# ...

# %%
import matplotlib.pyplot as plt

predicted = newPredictions.iloc[:,-1]     # Last column
actual = newPredictions.iloc[:,-2]        # 2nd last column

plt.scatter(actual, predicted)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Actul Vs Predicted')
plt.savefig("result-scatter-plot.jpg", dpi=300)
plt.show()

# %%
from IPython.display import FileLink
FileLink("result-scatter-plot.jpg")
# Out:
# C:\Users\pratham\result-scatter-plot.jpg

# %%
from IPython.display import FileLink
newPredictions.to_csv("NewPredictions.csv",index=False)
FileLink("NewPredictions.csv")
# Out:
# C:\Users\pratham\NewPredictions.csv

# %%
sm=save_model(rfModel, 'rfModelFile')
# Out:
# Transformation Pipeline and Model Successfully Saved

# %%
from IPython.display import FileLink
FileLink("rfModelFile.pk1")
# Out:
# C:\Users\pratham\rfModelFile.pk1

# %%
from IPython.display import FileLink
from pycaret.regression import save_model

# Assuming rfModel is a trained model
rfModel = create_model('rf')  # Example: Create a RandomForestClassifier model

# Save the trained model to a file
save_model(rfModel, 'rfModelFile')

# Create a link to download the saved model file
link = FileLink('rfModelFile.pkl')

# Display the link for download
link
# Out:
# <style type="text/css">
# #T_dcc7e_row10_col0, #T_dcc7e_row10_col1, #T_dcc7e_row10_col2, #T_dcc7e_row10_col3, #T_dcc7e_row10_col4, #T_dcc7e_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_dcc7e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dcc7e_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_dcc7e_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_dcc7e_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_dcc7e_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_dcc7e_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_dcc7e_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...

# %%
from ipywidgets import FileUpload

# Create the file upload widget
upload_widget = FileUpload()

# Display the file upload widget
upload_widget
# Out:
# FileUpload(value=(), description='Upload')

# %%
rfMode=load_model('rfModelFile')
# Out:
# Transformation Pipeline and Model Successfully Loaded

# %%
newPredictions = predict_model(rfModel, data = newDataSet)    # Uncomment and run again
newPredictions            # Uncomment and run again
# Out:
# <style type="text/css">
# </style>
# <table id="T_eaa14">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_eaa14_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_eaa14_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_eaa14_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_eaa14_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_eaa14_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_eaa14_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_eaa14_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_eaa14_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_eaa14_row0_col0" class="data row0 col0" >Random Forest Regressor</td>
#       <td id="T_eaa14_row0_col1" class="data row0 col1" >1.2210</td>
# ...

# %%
rfModel = create_model('rf')
# Out:
# <style type="text/css">
# #T_76833_row10_col0, #T_76833_row10_col1, #T_76833_row10_col2, #T_76833_row10_col3, #T_76833_row10_col4, #T_76833_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_76833">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_76833_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_76833_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_76833_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_76833_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_76833_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_76833_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...

# %%
plot_model(rfModel, plot='error')

# %%
plot_model(rfModel, plot='learning')

# %%
plot_model(rfModel, plot='vc')

# %%
plot_model(rfModel, plot='parameter')
# Out:
#                              Parameters
# bootstrap                          True
# ccp_alpha                           0.0
# criterion                 squared_error
# max_depth                          None
# max_features                        1.0
# max_leaf_nodes                     None
# max_samples                        None
# min_impurity_decrease               0.0
# min_samples_leaf                      1
# min_samples_split                     2
# min_weight_fraction_leaf            0.0
# monotonic_cst                      None
# n_estimators                        100
# n_jobs                               -1
# oob_score                         False
# random_state                       1917
# verbose                               0
# warm_start                        False

# %%
rfModel = create_model('rf', verbose=False)
plot_model(rfModel, plot='feature')

# %%
etModel = create_model('et', verbose=False)
plot_model(etModel, plot='feature')

# %%
dtModel = create_model('dt', verbose=False)
plot_model(dtModel, plot='feature')

# %%
dtModel = create_model('dt')
# Out:
# <style type="text/css">
# #T_fba94_row10_col0, #T_fba94_row10_col1, #T_fba94_row10_col2, #T_fba94_row10_col3, #T_fba94_row10_col4, #T_fba94_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_fba94">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fba94_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_fba94_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_fba94_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_fba94_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_fba94_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_fba94_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...

# %%
plot_model(dtModel, plot='parameter')
# Out:
#                              Parameters
# ccp_alpha                           0.0
# criterion                 squared_error
# max_depth                          None
# max_features                       None
# max_leaf_nodes                     None
# min_impurity_decrease               0.0
# min_samples_leaf                      1
# min_samples_split                     2
# min_weight_fraction_leaf            0.0
# monotonic_cst                      None
# random_state                       1917
# splitter                           best

# %%
dtModelTuned = tune_model(dtModel, n_iter=200)
# Out:
# <style type="text/css">
# #T_37443_row10_col0, #T_37443_row10_col1, #T_37443_row10_col2, #T_37443_row10_col3, #T_37443_row10_col4, #T_37443_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_37443">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_37443_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_37443_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_37443_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_37443_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_37443_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_37443_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...

# %%
plot_model(dtModelTuned, plot='parameter')
# Out:
#                              Parameters
# ccp_alpha                           0.0
# criterion                 squared_error
# max_depth                            14
# max_features                        1.0
# max_leaf_nodes                     None
# min_impurity_decrease             0.005
# min_samples_leaf                      6
# min_samples_split                    10
# min_weight_fraction_leaf            0.0
# monotonic_cst                      None
# random_state                       1917
# splitter                           best
